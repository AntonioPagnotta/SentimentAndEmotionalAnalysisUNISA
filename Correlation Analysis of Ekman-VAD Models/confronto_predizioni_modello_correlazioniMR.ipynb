# %%
import pandas as pd
#["Anger", "Disgust", "Fear", "Joy", "Neutral", "Sadness", "Surprise"]
data = {
    "emotion": ["Anger", "Disgust", "Fear", "Joy", "Neutral", "Sadness", "Surprise"],
    "V": [1.969, 1.680, 1.612, 3.992, 3.000, 1.629, 3.380],
    "A": [3.839, 3.295, 3.720, 3.516, 3.000, 3.159, 3.839],
    "D": [3.278, 2.887, 1.969, 3.295, 3.000, 2.139, 2.479]
}

# Creazione del DataFrame
df = pd.DataFrame(data)
print(df)
# Out:
#     emotion      V      A      D
# 0     Anger  1.969  3.839  3.278
# 1   Disgust  1.680  3.295  2.887
# 2      Fear  1.612  3.720  1.969
# 3       Joy  3.992  3.516  3.295
# 4   Neutral  3.000  3.000  3.000
# 5   Sadness  1.629  3.159  2.139
# 6  Surprise  3.380  3.839  2.479

# %%
from matplotlib import pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(figsize=(10, 6))
sns.lineplot(data=df, x='emotion', y='V', ax=ax)
ax.set_ylim(1, 5)
plt.show()

fig, ax = plt.subplots(figsize=(10, 6))
sns.lineplot(data=df, x='emotion', y='A', ax=ax)
ax.set_ylim(1, 5)
plt.show()

fig, ax = plt.subplots(figsize=(10, 6))
sns.lineplot(data=df, x='emotion', y='D', ax=ax)
ax.set_ylim(1, 5)
plt.show()

# %%
print("arpanghoshal_EkmanClassifier")

data1 = {
    "emotion": ["Anger", "Disgust", "Fear", "Joy", "Neutral", "Sadness", "Surprise"],
    "V": [2.514188, 2.394615, 2.526923, 3.282534, 2.949138, 2.435512, 2.873196],
    "A": [3.217173, 3.166154, 3.222308, 3.155608, 3.008867, 3.054016, 3.117451],
    "D": [3.117592, 2.969231, 2.817500, 3.144250, 3.054826, 2.834488, 3.009647]
}

df1 = pd.DataFrame(data1)
print(df1)

from matplotlib import pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(figsize=(10, 6))
sns.lineplot(data=df1, x='emotion', y='V', ax=ax)
sns.lineplot(data=df, x='emotion', y='V', ax=ax)
ax.set_ylim(1, 5)
plt.show()

fig, ax = plt.subplots(figsize=(10, 6))
sns.lineplot(data=df1, x='emotion', y='A', ax=ax)
sns.lineplot(data=df, x='emotion', y='A', ax=ax)
ax.set_ylim(1, 5)
plt.show()

fig, ax = plt.subplots(figsize=(10, 6))
sns.lineplot(data=df1, x='emotion', y='D', ax=ax)
sns.lineplot(data=df, x='emotion', y='D', ax=ax)
ax.set_ylim(1, 5)
plt.show()
# Out:
# arpanghoshal_EkmanClassifier
#     emotion         V         A         D
# 0     Anger  2.514188  3.217173  3.117592
# 1   Disgust  2.394615  3.166154  2.969231
# 2      Fear  2.526923  3.222308  2.817500
# 3       Joy  3.282534  3.155608  3.144250
# 4   Neutral  2.949138  3.008867  3.054826
# 5   Sadness  2.435512  3.054016  2.834488
# 6  Surprise  2.873196  3.117451  3.009647

# %%
print("SkyWater21_lvbert-lv-go-emotions-ekman")

data3 = {
    "emotion": ["Anger", "Disgust", "Fear", "Joy", "Neutral", "Sadness", "Surprise"],
    "V": [2.744048, 3, 3, 3.097123, 2.968040, 2.858000, 2.880796],
    "A": [3.085363, 3, 3, 3.084653, 3.021280, 2.864000, 3.083765],
    "D": [3.029948, 3, 3, 3.108119, 3.054517, 2.970000, 3.030663]
}

df3 = pd.DataFrame(data3)
print(df3)

from matplotlib import pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(figsize=(10, 6))
sns.lineplot(data=df3, x='emotion', y='V', ax=ax)
sns.lineplot(data=df, x='emotion', y='V', ax=ax)
ax.set_ylim(1, 5)
plt.show()

fig, ax = plt.subplots(figsize=(10, 6))
sns.lineplot(data=df3, x='emotion', y='A', ax=ax)
sns.lineplot(data=df, x='emotion', y='A', ax=ax)
ax.set_ylim(1, 5)
plt.show()

fig, ax = plt.subplots(figsize=(10, 6))
sns.lineplot(data=df3, x='emotion', y='D', ax=ax)
sns.lineplot(data=df, x='emotion', y='D', ax=ax)
ax.set_ylim(1, 5)
plt.show()
# Out:
# SkyWater21_lvbert-lv-go-emotions-ekman
#     emotion         V         A         D
# 0     Anger  2.744048  3.085363  3.029948
# 1   Disgust  3.000000  3.000000  3.000000
# 2      Fear  3.000000  3.000000  3.000000
# 3       Joy  3.097123  3.084653  3.108119
# 4   Neutral  2.968040  3.021280  3.054517
# 5   Sadness  2.858000  2.864000  2.970000
# 6  Surprise  2.880796  3.083765  3.030663

# %%
print("SkyWater21_rubert-base-cased-ru-go-emotions-ekman")

data2 = {
    "emotion": ["Anger", "Disgust", "Fear", "Joy", "Neutral", "Sadness", "Surprise"],
    "V": [2.809238, 1.630000, 2.630000, 3.106277, 2.9506078, 2.666875, 2.892648],
    "A": [3.111143, 3.910000, 2.880000, 3.101289, 3.018039, 3.103750, 3.089042],
    "D": [3.094508, 3.450000, 2.750000, 3.108882, 3.050071, 2.930625, 3.020873]
}

df2 = pd.DataFrame(data2)
print(df2)

from matplotlib import pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(figsize=(10, 6))
sns.lineplot(data=df2, x='emotion', y='V', ax=ax)
sns.lineplot(data=df, x='emotion', y='V', ax=ax)
ax.set_ylim(1, 5)
plt.show()

fig, ax = plt.subplots(figsize=(10, 6))
sns.lineplot(data=df2, x='emotion', y='A', ax=ax)
sns.lineplot(data=df, x='emotion', y='A', ax=ax)
ax.set_ylim(1, 5)
plt.show()

fig, ax = plt.subplots(figsize=(10, 6))
sns.lineplot(data=df2, x='emotion', y='D', ax=ax)
sns.lineplot(data=df, x='emotion', y='D', ax=ax)
ax.set_ylim(1, 5)
plt.show()
# Out:
# SkyWater21_rubert-base-cased-ru-go-emotions-ekman
#     emotion         V         A         D
# 0     Anger  2.809238  3.111143  3.094508
# 1   Disgust  1.630000  3.910000  3.450000
# 2      Fear  2.630000  2.880000  2.750000
# 3       Joy  3.106277  3.101289  3.108882
# 4   Neutral  2.950608  3.018039  3.050071
# 5   Sadness  2.666875  3.103750  2.930625
# 6  Surprise  2.892648  3.089042  3.020873
